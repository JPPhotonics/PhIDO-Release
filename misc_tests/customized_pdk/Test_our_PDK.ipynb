# %% [markdown]
# # Test our PDK

# %%
from gdsfactory.generic_tech import get_generic_pdk

genericPDK = get_generic_pdk()

LAYER = genericPDK.layers
layer_views = genericPDK.layer_views
layer_stack = genericPDK.layer_stack
cross_sections = genericPDK.cross_sections


import gdsfactory as gf

# %% [markdown]
# _bend_euler
# _bend_s
# _bezier_curve
# _directional_coupler
# _mmi1x2
# _mmi2x2
# _straight
# dc_mzi_2x2_heater_doped_si_cband
# dc_mzi_2x2_pindiode_cband
# heater_doped_si_cband
# heater_doped_si_oband
# heater_tin_cband
# heater_tin_oband
# heater_tin_undercut_multipass
# mzi1
# mzi_1x1_heater_doped_si_cband
# mzi_1x1_heater_doped_si_oband
# mzi_1x1_heater_tin_cband
# mzi_1x1_heater_tin_oband
# mzi_1x1_pindiode_cband
# mzi_1x1_pindiode_oband
# mzi_1x2_heater_doped_si_cband
# mzi_1x2_heater_tin_cband
# mzi_1x2_pindiode_cband
# mzi_2x2_heater
# mzi_2x2_heater_doped_si_cband
# mzi_2x2_heater_tin_cband
# mzi_2x2_heater_undercut_multipass
# mzi_2x2_nested_cband
# mzi_2x2_pindiode_cband
# mzi_2x2_pn_diode
# mzi_arm
# mzi_pn
# mzm1
# pindiode_cband
# pindiode_oband
# pndiode
# voa_dopedsilicon
# voa_to
# voa_to_undercut_multipass
# wdm1
# wdm2
# wdm_mrr1
# wdm_mzi1x4
# wdm_mzi1x8

# %%
import sys

sys.path.append("/Users/vahid/Downloads/PhotonicsAI_Project")

from PhotonicsAI.KnowledgeBase.DesignLibrary._bend_s import _bend_s
from PhotonicsAI.KnowledgeBase.DesignLibrary._bezier_curve import _bezier_curve
from PhotonicsAI.KnowledgeBase.DesignLibrary._directional_coupler import (
    _directional_coupler,
)
from PhotonicsAI.KnowledgeBase.DesignLibrary._mmi1x2 import _mmi1x2
from PhotonicsAI.KnowledgeBase.DesignLibrary._mmi2x2 import _mmi2x2
from PhotonicsAI.KnowledgeBase.DesignLibrary.bend_euler import _bend_euler
from PhotonicsAI.KnowledgeBase.DesignLibrary.dc_mzi_2x2_heater_doped_si_cband import (
    dc_mzi_2x2_heater_doped_si_cband,
)

# from PhotonicsAI.KnowledgeBase.DesignLibrary.dc_mzi_2x2_pindiode_cband import dc_mzi_2x2_pindiode_cband
from PhotonicsAI.KnowledgeBase.DesignLibrary.heater_doped_si_cband import (
    heater_doped_si_cband,
)

# from PhotonicsAI.KnowledgeBase.DesignLibrary.heater_doped_si_oband import heater_doped_si_oband
from PhotonicsAI.KnowledgeBase.DesignLibrary.heater_tin_cband import heater_tin_cband

# from PhotonicsAI.KnowledgeBase.DesignLibrary.heater_tin_oband import heater_tin_oband
# from PhotonicsAI.KnowledgeBase.DesignLibrary.heater_tin_undercut_multipass import heater_tin_undercut_multipass
from PhotonicsAI.KnowledgeBase.DesignLibrary.mzi1 import mzi1

# from PhotonicsAI.KnowledgeBase.DesignLibrary.mzi_1x1_heater_doped_si_cband import mzi_1x1_heater_doped_si_cband
# from PhotonicsAI.KnowledgeBase.DesignLibrary.mzi_1x1_heater_doped_si_oband import mzi_1x1_heater_doped_si_oband
from PhotonicsAI.KnowledgeBase.DesignLibrary.mzi_1x1_heater_tin_cband import (
    mzi_1x1_heater_tin_cband,
)

# from PhotonicsAI.KnowledgeBase.DesignLibrary.mzi_1x1_heater_tin_oband import mzi_1x1_heater_tin_oband
from PhotonicsAI.KnowledgeBase.DesignLibrary.mzi_1x1_pindiode_cband import (
    mzi_1x1_pindiode_cband,
)

# from PhotonicsAI.KnowledgeBase.DesignLibrary.mzi_1x1_pindiode_oband import mzi_1x1_pindiode_oband
# from PhotonicsAI.KnowledgeBase.DesignLibrary.mzi_1x2_heater_doped_si_cband import mzi_1x2_heater_doped_si_cband
# from PhotonicsAI.KnowledgeBase.DesignLibrary.mzi_1x2_heater_tin_cband import mzi_1x2_heater_tin_cband
from PhotonicsAI.KnowledgeBase.DesignLibrary.mzi_1x2_pindiode_cband import (
    mzi_1x2_pindiode_cband,
)

# from PhotonicsAI.KnowledgeBase.DesignLibrary.mzi_2x2_heater import mzi_2x2_heater
# from PhotonicsAI.KnowledgeBase.DesignLibrary.mzi_2x2_heater_doped_si_cband import mzi_2x2_heater_doped_si_cband
from PhotonicsAI.KnowledgeBase.DesignLibrary.mzi_2x2_heater_tin_cband import (
    mzi_2x2_heater_tin_cband,
)

# from PhotonicsAI.KnowledgeBase.DesignLibrary.mzi_2x2_heater_undercut_multipass import mzi_2x2_heater_undercut_multipass
# from PhotonicsAI.KnowledgeBase.DesignLibrary.mzi_2x2_nested_cband import mzi_2x2_nested_cband
from PhotonicsAI.KnowledgeBase.DesignLibrary.mzi_2x2_pindiode_cband import (
    mzi_2x2_pindiode_cband,
)
from PhotonicsAI.KnowledgeBase.DesignLibrary.mzi_2x2_pn_diode import mzi_2x2_pn_diode
from PhotonicsAI.KnowledgeBase.DesignLibrary.mzi_arm import mzi_arm

# from PhotonicsAI.KnowledgeBase.DesignLibrary.mzi_pn import mzi_pn
# from PhotonicsAI.KnowledgeBase.DesignLibrary.mzm1 import mzm1
from PhotonicsAI.KnowledgeBase.DesignLibrary.pindiode_cband import pindiode_cband

# from PhotonicsAI.KnowledgeBase.DesignLibrary.pindiode_oband import pindiode_oband
from PhotonicsAI.KnowledgeBase.DesignLibrary.pndiode import pndiode
from PhotonicsAI.KnowledgeBase.DesignLibrary.straight import _straight

# from PhotonicsAI.KnowledgeBase.DesignLibrary.voa_dopedsilicon import voa_dopedsilicon
# from PhotonicsAI.KnowledgeBase.DesignLibrary.voa_to import voa_to
# from PhotonicsAI.KnowledgeBase.DesignLibrary.voa_to_undercut_multipass import voa_to_undercut_multipass
# from PhotonicsAI.KnowledgeBase.DesignLibrary.wdm1 import wdm1
# from PhotonicsAI.KnowledgeBase.DesignLibrary.wdm2 import wdm2
# from PhotonicsAI.KnowledgeBase.DesignLibrary.wdm_mrr1 import wdm_mrr1
from PhotonicsAI.KnowledgeBase.DesignLibrary.wdm_mzi1x4 import wdm_mzi1x4
# from PhotonicsAI.KnowledgeBase.DesignLibrary.wdm_mzi1x8 import wdm_mzi1x8

# %%
cells = dict(
    _bend_euler=_bend_euler,
    _bend_s=_bend_s,
    _bezier_curve=_bezier_curve,
    _directional_coupler=_directional_coupler,
    _mmi1x2=_mmi1x2,
    _mmi2x2=_mmi2x2,
    _straight=_straight,
    dc_mzi_2x2_heater_doped_si_cband=dc_mzi_2x2_heater_doped_si_cband,
    # dc_mzi_2x2_pindiode_cband=dc_mzi_2x2_pindiode_cband,
    heater_doped_si_cband=heater_doped_si_cband,
    # heater_doped_si_oband=heater_doped_si_oband,
    heater_tin_cband=heater_tin_cband,
    # heater_tin_oband=heater_tin_oband,
    # heater_tin_undercut_multipass=heater_tin_undercut_multipass,
    mzi1=mzi1,
    # mzi_1x1_heater_doped_si_cband=mzi_1x1_heater_doped_si_cband,
    # mzi_1x1_heater_doped_si_oband=mzi_1x1_heater_doped_si_oband,
    mzi_1x1_heater_tin_c=mzi_1x1_heater_tin_cband,
    # mzi_1x1_heater_tin_o=mzi_1x1_heater_tin_oband,
    mzi_1x1_pindiode_cband=mzi_1x1_pindiode_cband,
    # mzi_1x1_pindiode_oband=mzi_1x1_pindiode_oband,
    # mzi_1x2_heater_doped_si_cband=mzi_1x2_heater_doped_si_cband,
    # mzi_1x2_heater_tin_cband=mzi_1x2_heater_tin_cband,
    mzi_1x2_pindiode_cband=mzi_1x2_pindiode_cband,
    # mzi_2x2_heater=mzi_2x2_heater,
    # mzi_2x2_heater_doped_si_cband=mzi_2x2_heater_doped_si_cband,
    mzi_2x2_heater_tin_cb=mzi_2x2_heater_tin_cband,
    # mzi_2x2_heater_undercut_multipass=mzi_2x2_heater_undercut_multipass,
    # mzi_2x2_nested_cb=mzi_2x2_nested_cband,
    mzi_2x2_pindiode_cband=mzi_2x2_pindiode_cband,
    mzi_2x2_pn_diode=mzi_2x2_pn_diode,
    mzi_arm=mzi_arm,
    # mzi_pn=mzi_pn,
    # mzm1=mzm1,
    pindiode_cband=pindiode_cband,
    # pindiode_oband=pindiode_oband,
    pndiode=pndiode,
    # voa_dopedsilicon=voa_dopedsilicon,
    # voa_to=voa_to,
    # voa_to_undercut_multipass=voa_to_undercut_multipass,
    # wdm1=wdm1,
    # wdm2=wdm2,
    # wdm_mrr1=wdm_mrr1,
    wdm_mzi1x4=wdm_mzi1x4,
    # wdm_mzi1x8=wdm_mzi1x8,
)

DemoPDK = gf.Pdk(
    name="DemoPDK",
    layers=LAYER,
    cross_sections=cross_sections,
    cells=cells,
    layer_views=layer_views,
)
DemoPDK.activate()

# %%
DemoPDK.cells

# %%
import sys

sys.path.append("/Users/vahid/Downloads/PhotonicsAI_Project")

from PhotonicsAI.Photon.DemoPDK import *

netlist1 = """
instances:
  C1:
    component: mzi_2x2_pn_diode
    info: {ports: 2x2}
  C2:
    component: voa_to
    info: {ports: 1x1}
connections:
  C1,o3: C2,o1
name: new_circuit
"""

netlist2 = """
name: new_circuit
instances:
  C1:
    component: mzi_2x2_pn_diode
    info: {ports: 2x2}
  C2:
    component: voa_to
    info: {ports: 1x1}
placements:
    C2:
      x: 100
      y: 100
routes:
  optical:
    links:
      C1,o2: C2,o1
"""

netlist3 = """
instances:
  C1:
    component: _mmi1x2
    info:
      ports: 1x2
placements:
  C1:
    x: 0
    y: 0
routes:
  optical:
    links:
      {}
name: new_circuit_69945604"""


netlist4 = """
instances:
  C1:
    component: dc_mzi_2x2_heater_doped_si_cband
    info:
      ports: 2x2
  C2:
    component: dc_mzi_2x2_heater_doped_si_cband
    info:
      ports: 2x2
  C3:
    component: dc_mzi_2x2_heater_doped_si_cband
    info:
      ports: 2x2
  C4:
    component: dc_mzi_2x2_heater_doped_si_cband
    info:
      ports: 2x2
  C5:
    component: dc_mzi_2x2_heater_doped_si_cband
    info:
      ports: 2x2
name: cascaded_mzi_circuit_62325805
placements:
  C1:
    x: 0
    y: 0
  C2:
    x: 1000
    y: 0
  C3:
    x: 2000
    y: 0
  C4:
    x: 3000
    y: 0
  C5:
    x: 4000
    y: 0
routes:
  optical:
    links:
      C1,o3: C2,o1
      C1,o4: C2,o2
      C2,o3: C3,o1
      C2,o4: C3,o2
      C3,o3: C4,o1
      C3,o4: C4,o2
      C4,o3: C5,o1
      C4,o4: C5,o2
"""


c = gf.read.from_yaml(netlist4)
c.plot()

# %%
import gdsfactory as gf

c = gf.Component()
mmi1 = c << gf.components.mmi1x2()
mmi2 = c << gf.components.mmi1x2()
mmi2.dmove((100, 50))
route = gf.routing.route_single(
    c, port1=mmi1.ports["o2"], port2=mmi2.ports["o1"], bend=gf.components.bend_euler
)
c.write_netlist("dummy.yaml")


# with open('dummy.yaml', 'r') as file:
#     yaml_string = file.read()
# c = gf.read.from_yaml(yaml_string)

c.plot()

# %%
DemoPDK.get_component("pindiode_cband").dxsize
DemoPDK.get_component("pindiode_cband").dysize
# pindiode_cband

# %%
import gdsfactory as gf

c = gf.Component()
mmi1 = c << gf.components.mmi1x2()

c.get_netlist()

# %%
c = gf.Component()
c << DemoPDK.get_component("_mmi1x2")
c.get_netlist()

# %%
import sys

sys.path.append("/Users/vahid/Downloads/PhotonicsAI_Project")

from PhotonicsAI.Photon.DemoPDK import *

print(DemoPDK.cells)

# %%
import sys

sys.path.append("/Users/vahid/Downloads/PhotonicsAI_Project")

from PhotonicsAI.Photon.DemoPDK import *

netlist3 = """
instances:
  C1:
    component: _mmi1x2
    info:
      ports: 1x2
    settings:
      length_mmi: 20
placements:
  C1:
    x: 0
    y: 0
"""

c = gf.read.from_yaml(netlist3)
c.plot()

# %%
import sys

sys.path.append("/Users/vahid/Downloads/PhotonicsAI_Project")

from PhotonicsAI.Photon.DemoPDK import *

netlist = """
instances:
  C1:
    component: wdm_mzi1x4
    info:
      ports: 1x4
  C2:
    component: dc_mzi_2x2_heater_doped_si_cband
    info:
      ports: 2x2
  C3:
    component: dc_mzi_2x2_heater_doped_si_cband
    info:
      ports: 2x2
  C4:
    component: dc_mzi_2x2_heater_doped_si_cband
    info:
      ports: 2x2
  C5:
    component: dc_mzi_2x2_heater_doped_si_cband
    info:
      ports: 2x2
name: new_circuit_9a6c508d7d2e497d97f8c9b6560a14cb"""


c = gf.read.from_yaml(netlist)
c.plot()
gf_netlist_dict = c.get_netlist(recursive=False)

# %%
from gdsfactory.generic_tech import get_generic_pdk

genericPDK = get_generic_pdk()

LAYER = genericPDK.layers
layer_views = genericPDK.layer_views
layer_stack = genericPDK.layer_stack
cross_sections = genericPDK.cross_sections


import glob
import importlib
import sys

import gdsfactory as gf
import sax

sys.path.append("/Users/vahid/Downloads/PhotonicsAI_Project")


def list_python_files(directory):
    """Lists all Python files in the given directory using glob."""
    # Use glob to list all .py files, exclude __init__.py
    return [
        f.split("/")[-1][:-3]
        for f in glob.glob(f"{directory}/*.py")
        if not f.endswith("__init__.py")
    ]


def import_modules(module_names):
    """Imports the specified function from each module in the given package and returns them in a dictionary."""
    functions = {}
    for module_name in module_names:
        full_module_name = f"PhotonicsAI.KnowledgeBase.DesignLibrary.{module_name}"
        module = importlib.import_module(full_module_name)
        func = getattr(module, module_name)
        globals()[module_name] = func
        functions[module_name] = func
    return functions


module_names = list_python_files("../../KnowledgeBase/DesignLibrary/")
cells = import_modules(module_names)

DemoPDK = gf.Pdk(
    name="DemoPDK",
    layers=LAYER,
    cross_sections=cross_sections,
    cells=cells,
    layer_views=layer_views,
)
DemoPDK.activate()

# %%
netlist1 = """
instances:
  C1:
    component: _mmi1x2
    info:
      dx: 32.8
      dy: 3.8000000000000003
      ports: 1x2
    settings:
      gap_mmi: 0.25
      length_mmi: 40
      length_taper: 10
      width_mmi: 3.8
      width_taper: 1.4
placements:
  C1:
    x: 3.2810000000000024
    y: 1.074
"""

from pprint import pprint

c = gf.read.from_yaml(netlist1)
# c.plot()
pprint(c.get_netlist())

print("=====================")
print("=======RECURSIVE")

gf_netlist_dict_recursive = c.get_netlist(recursive=True)
recursive_netlist = sax.RecursiveNetlist.model_validate(gf_netlist_dict_recursive)
print("Required Models ==>", sax.get_required_circuit_models(recursive_netlist))
print("=====================")
print(gf_netlist_dict_recursive)

# %%
import PhotonicsAI.KnowledgeBase.DesignLibrary._mmi1x2 as _mmi1x2_module

_c, info = sax.circuit(gf_netlist_dict_recursive, _mmi1x2_module.get_model())
# _mmi1x2

# %%
c1 = gf.Component()
ref1 = c1 << _mmi1x2(width_mmi=7)
# c1.plot()

c1.get_netlist()

recnet1 = sax.RecursiveNetlist.model_validate(c1.get_netlist(recursive=True))
recnet1 = sax.RecursiveNetlist.model_validate(c1.get_netlist(recursive=True))

print("Required Models ==>", sax.get_required_circuit_models(recnet1))
print(recnet1)

print("==============")
